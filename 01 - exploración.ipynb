# %%
#Importar las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Se lee el archivo train.csv y se le asigna a la variable df
df = pd.read_csv('data/train.csv')
df
# Out:
#             ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 0       904256    20212                           ENFERMERIA
# 1       645256    20212                              DERECHO
# 2       308367    20203                MERCADEO Y PUBLICIDAD
# 3       470353    20195           ADMINISTRACION DE EMPRESAS
# 4       989032    20212                           PSICOLOGIA
# ...        ...      ...                                  ...
# 692495   25096    20195                             BIOLOGIA
# 692496  754213    20212                           PSICOLOGIA
# 692497  504185    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620    20195                           PSICOLOGIA
# 692499  933374    20195                           PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                      BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1                   ATLANTICO  Entre 2.5 millones y menos de 4 millones
# ...

# %%
#Observar las columnas y el tamaño del df
df.columns, df.shape
# Out:
# (Index(['ID', 'PERIODO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#         'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
#         'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE',
#         'FAMI_EDUCACIONMADRE', 'ESTU_PAGOMATRICULAPROPIO',
#         'RENDIMIENTO_GLOBAL'],
#        dtype='object'),
#  (692500, 12))

# %%
#Para obtener información general del df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              692500 non-null  int64
#  1   PERIODO                         692500 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         661643 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            660363 non-null  object
#  7   FAMI_TIENEINTERNET              665871 non-null  object
#  8   FAMI_EDUCACIONPADRE             669322 non-null  object
#  9   FAMI_EDUCACIONMADRE             668836 non-null  object
#  10  ESTU_PAGOMATRICULAPROPIO        686002 non-null  object
#  11  RENDIMIENTO_GLOBAL              692500 non-null  object
# ...

# %%
#Para ver el estudio de cada estudiante (ya que el df está compuesto por series)
s1 = df["ESTU_PRGM_ACADEMICO"]
s1
# Out:
# 0                                  ENFERMERIA
# 1                                     DERECHO
# 2                       MERCADEO Y PUBLICIDAD
# 3                  ADMINISTRACION DE EMPRESAS
# 4                                  PSICOLOGIA
#                          ...
# 692495                               BIOLOGIA
# 692496                             PSICOLOGIA
# 692497    ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498                             PSICOLOGIA
# 692499                             PSICOLOGIA
# Name: ESTU_PRGM_ACADEMICO, Length: 692500, dtype: object

# %%
#Para establecer ID como indice para identificar mejor a los estudiantes
df_change_index = df.copy()
df_change_index.set_index("ID", inplace=True)
df_change_index.ESTU_PRGM_ACADEMICO
# Out:
# ID
# 904256                             ENFERMERIA
# 645256                                DERECHO
# 308367                  MERCADEO Y PUBLICIDAD
# 470353             ADMINISTRACION DE EMPRESAS
# 989032                             PSICOLOGIA
#                          ...
# 25096                                BIOLOGIA
# 754213                             PSICOLOGIA
# 504185    ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 986620                             PSICOLOGIA
# 933374                             PSICOLOGIA
# Name: ESTU_PRGM_ACADEMICO, Length: 692500, dtype: object

# %%
#Para filtrar por estratos iguales a 3
df_estrato_3 = df[df["FAMI_ESTRATOVIVIENDA"] == "Estrato 3"]
df_estrato_3
# Out:
#             ID  PERIODO                                ESTU_PRGM_ACADEMICO  \
# 0       904256    20212                                         ENFERMERIA
# 1       645256    20212                                            DERECHO
# 2       308367    20203                              MERCADEO Y PUBLICIDAD
# 4       989032    20212                                         PSICOLOGIA
# 12      858669    20183                                HOTELERIA Y TURISMO
# ...        ...      ...                                                ...
# 692485  945114    20195                         ADMINISTRACIÓN DE EMPRESAS
# 692489  481885    20195                              INGENIERIA INDUSTRIAL
# 692494  649690    20212  LICENCIATURA EN EDUCACION BASICA CON ENFASIS E...
# 692496  754213    20212                                         PSICOLOGIA
# 692497  504185    20183                ADMINISTRACIÓN EN SALUD OCUPACIONAL
#
# ...

# %%
#Mostrar cantidad de registros por el departamento
df.groupby("ESTU_PRGM_DEPARTAMENTO").size()
# Out:
# ESTU_PRGM_DEPARTAMENTO
# AMAZONAS               40
# ANTIOQUIA           83607
# ARAUCA                589
# ATLANTICO           41020
# BOGOTÁ             282159
# BOLIVAR             20629
# BOYACA              14048
# CALDAS              11640
# CAQUETA              2659
# CASANARE             1852
# CAUCA               11471
# CESAR                8279
# CHOCO                4289
# CORDOBA             12188
# CUNDINAMARCA        14018
# GUAVIARE               37
# HUILA                9995
# LA GUAJIRA           4778
# MAGDALENA            9512
# META                 7910
# NARIÑO              13454
# NORTE SANTANDER     22588
# PUTUMAYO              795
# QUINDIO              8229
# RISARALDA           12679
# SAN ANDRES             10
# SANTANDER           28828
# SUCRE                8674
# TOLIMA              11921
# VALLE               44588
# VAUPES                 14
# dtype: int64

# %%
#También para saber la cantidad de registros por estrato
df.groupby("FAMI_ESTRATOVIVIENDA").size()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      111991
# Estrato 2      232671
# Estrato 3      210685
# Estrato 4       65514
# Estrato 5       23608
# Estrato 6       12605
# Sin Estrato      3289
# dtype: int64

# %%
#Para contar datos nulos en cada columna
df.isna().sum()
# Out:
# ID                                    0
# PERIODO                               0
# ESTU_PRGM_ACADEMICO                   0
# ESTU_PRGM_DEPARTAMENTO                0
# ESTU_VALORMATRICULAUNIVERSIDAD     6287
# ESTU_HORASSEMANATRABAJA           30857
# FAMI_ESTRATOVIVIENDA              32137
# FAMI_TIENEINTERNET                26629
# FAMI_EDUCACIONPADRE               23178
# FAMI_EDUCACIONMADRE               23664
# ESTU_PAGOMATRICULAPROPIO           6498
# RENDIMIENTO_GLOBAL                    0
# dtype: int64

# %%
#Grafiquemos los estratos
plt.plot(df.groupby("FAMI_ESTRATOVIVIENDA").size())
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>
